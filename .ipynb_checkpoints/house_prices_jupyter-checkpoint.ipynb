# %%
import pandas as pd
import numpy as np
import pylab as plt
from sklearn import linear_model as lm
import seaborn as sbn

# %% [markdown]
# This will be a regression based notebook for the kaggle competition found here: https://www.kaggle.com/c/house-prices-advanced-regression-techniques.  The goal is to utilize multivariate regression before implementing regularizers ridge and lasso.
#
#  We first perform some exploratory analysis

# %%
df = pd.read_csv('data/train.csv')
df.set_index('Id', inplace= True)
print(df.SalePrice.describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# From intro stats lets check the data with the 68-95-99.7 rule with respect to one-, two-, and three-standard deviations

# %%
def trim(df,std_dev=1, scale = False, return_df = False):
    mu = df.SalePrice.mean()
    sigma = df.SalePrice.std()
    if scale:
        scale = 100000
    else:
        scale = 1
    trimmed_df = df.loc[(abs(df.SalePrice) <= (mu + std_dev*sigma))]
    data = trimmed_df.SalePrice
    if return_df:
        return trimmed_df
    else:
        label = str(std_dev) + "-Sigma, " + str(round(100*data.shape[0]/df.SalePrice.shape[0],2)) + "% of dataset"
        sbn.distplot(data/scale, kde_kws = {"label": label})
    

sbn.distplot(df.SalePrice/100000, kde_kws={"label": "All data"})
trim(df,1,True)
trim(df,2,True)
trim(df,3,True)

# %%
trim(df,1,True)
trim(df,2,True)
trim(df,3,True)
plt.title('Scaled Standard Deviations')
# Out:
# Text(0.5, 1.0, 'Scaled Standard Deviations')

# %% [markdown]
# To keep as many records as possible, we subset the data on records within 2 standard deviations of the mean.  Next we'll try to eliminate redundant numerical features by examing the absolute-correlation matrix:

# %%
df = trim(df,2,return_df = True)
abs_corr = df.select_dtypes(exclude = ['object']).drop(columns = 'SalePrice').corr().abs()
abs_corr
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000     0.392228  0.149784     0.066938     0.070390
# LotFrontage      0.392228     1.000000  0.597121     0.197700     0.042068
# LotArea          0.149784     0.597121  1.000000     0.069688     0.004736
# OverallQual      0.066938     0.197700  0.069688     1.000000     0.069987
# OverallCond      0.070390     0.042068  0.004736     0.069987     1.000000
# YearBuilt        0.045547     0.093630  0.000879     0.560243     0.361273
# YearRemodAdd     0.055045     0.061756  0.012266     0.531549     0.094132
# MasVnrArea       0.046793     0.149266  0.089963     0.325471     0.117478
# BsmtFinSF1       0.050490     0.215938  0.203337     0.152451     0.019789
# BsmtFinSF2       0.066068     0.046010  0.057341     0.049982     0.039169
# BsmtUnfSF        0.138248     0.115849  0.014348     0.308265     0.138566
# TotalBsmtSF      0.225233     0.360862  0.252106     0.465296     0.151164
# 1stFlrSF         0.241012     0.437161  0.307576     0.387224     0.131810
# 2ndFlrSF         0.313043     0.050693  0.046460     0.287385     0.025060
# LowQualFinSF     0.043971     0.039604  0.001468     0.050482     0.001066
# GrLivArea        0.099548     0.373698  0.269885     0.535931     0.076343
# BsmtFullBath     0.017436     0.081942  0.119990     0.067432     0.038811
# BsmtHalfBath     0.010310     0.002009  0.068131     0.035747     0.118032
# FullBath         0.148959     0.159275  0.120571     0.531603     0.197992
# HalfBath         0.182639     0.032619  0.005157     0.251406     0.058918
# BedroomAbvGr     0.036268     0.268810  0.142885     0.105628     0.001465
# KitchenAbvGr     0.281743     0.003427  0.012276     0.183122     0.091773
# TotRmsAbvGrd     0.056000     0.328514  0.186060     0.359457     0.049039
# Fireplaces       0.033388     0.239380  0.280243     0.351022     0.019119
# GarageYrBlt      0.103931     0.036705  0.043608     0.525540     0.315499
# GarageCars       0.018703     0.249418  0.147060     0.547075     0.173668
# GarageArea       0.081897     0.317754  0.182937     0.507132     0.139268
# WoodDeckSF       0.000569     0.071149  0.175248     0.193692     0.005840
# OpenPorchSF      0.000758     0.127719  0.102030     0.286366     0.027794
# EnclosedPorch    0.014806     0.011869  0.009130     0.105612     0.071737
# 3SsnPorch        0.047031     0.073082  0.031732     0.028651     0.031397
# ScreenPorch      0.034613     0.042204  0.042184     0.054074     0.045030
# PoolArea         0.007323     0.188812  0.098503     0.051522     0.002206
# MiscVal          0.008987     0.009436  0.050596     0.026364     0.068612
# MoSold           0.016272     0.013754  0.001977     0.071711     0.001123
# YrSold           0.020575     0.010652  0.030752     0.022683     0.049258
#
#                YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.045547      0.055045    0.046793    0.050490    0.066068
# LotFrontage     0.093630      0.061756    0.149266    0.215938    0.046010
# LotArea         0.000879      0.012266    0.089963    0.203337    0.057341
# OverallQual     0.560243      0.531549    0.325471    0.152451    0.049982
# OverallCond     0.361273      0.094132    0.117478    0.019789    0.039169
# YearBuilt       1.000000      0.578580    0.283329    0.212296    0.041955
# YearRemodAdd    0.578580      1.000000    0.128688    0.086900    0.058312
# MasVnrArea      0.283329      0.128688    1.000000    0.214281    0.060987
# BsmtFinSF1      0.212296      0.086900    0.214281    1.000000    0.053041
# BsmtFinSF2      0.041955      0.058312    0.060987    0.053041    1.000000
# BsmtUnfSF       0.140218      0.173345    0.087271    0.519930    0.213871
# TotalBsmtSF     0.354449      0.250803    0.292961    0.483711    0.118721
# 1stFlrSF        0.239253      0.193163    0.265290    0.396819    0.115850
# 2ndFlrSF        0.000594      0.131167    0.122710    0.168553    0.094508
# LowQualFinSF    0.170810      0.065516    0.068361    0.057378    0.017497
# GrLivArea       0.160936      0.252658    0.297979    0.142109    0.005098
# BsmtFullBath    0.166703      0.102733    0.058647    0.633950    0.159734
# BsmtHalfBath    0.035635      0.007727    0.031330    0.074996    0.072969
# FullBath        0.460406      0.425358    0.218908    0.020895    0.072672
# HalfBath        0.236918      0.169456    0.166890    0.025546    0.022388
# BedroomAbvGr    0.071990      0.045991    0.103919    0.091173    0.013726
# KitchenAbvGr    0.171162      0.144229    0.025051    0.074976    0.042662
# TotRmsAbvGrd    0.050267      0.148205    0.203931    0.021385    0.028535
# Fireplaces      0.122794      0.078679    0.214087    0.216898    0.049996
# GarageYrBlt     0.820937      0.627602    0.207071    0.110162    0.079981
# GarageCars      0.516065      0.387173    0.290432    0.157555    0.027148
# GarageArea      0.456717      0.337499    0.293441    0.236756    0.002661
# WoodDeckSF      0.205990      0.188400    0.108458    0.179233    0.085287
# OpenPorchSF     0.173853      0.209648    0.112179    0.092036    0.013216
# EnclosedPorch   0.396460      0.190719    0.113717    0.102182    0.037876
# 3SsnPorch       0.024459      0.040240    0.015432    0.011988    0.029287
# ScreenPorch     0.045819      0.047946    0.070172    0.073345    0.090358
# PoolArea        0.000428      0.003406    0.027160    0.127861    0.047874
# MiscVal         0.031705      0.006896    0.026903    0.009386    0.004457
# MoSold          0.008248      0.017601    0.009345    0.022549    0.012129
# YrSold          0.015741      0.038535    0.012538    0.012225    0.025953
#
#                ...  GarageArea  WoodDeckSF  OpenPorchSF  EnclosedPorch  \
# MSSubClass     ...    0.081897    0.000569     0.000758       0.014806
# LotFrontage    ...    0.317754    0.071149     0.127719       0.011869
# LotArea        ...    0.182937    0.175248     0.102030       0.009130
# OverallQual    ...    0.507132    0.193692     0.286366       0.105612
# OverallCond    ...    0.139268    0.005840     0.027794       0.071737
# YearBuilt      ...    0.456717    0.205990     0.173853       0.396460
# YearRemodAdd   ...    0.337499    0.188400     0.209648       0.190719
# MasVnrArea     ...    0.293441    0.108458     0.112179       0.113717
# BsmtFinSF1     ...    0.236756    0.179233     0.092036       0.102182
# BsmtFinSF2     ...    0.002661    0.085287     0.013216       0.037876
# BsmtUnfSF      ...    0.180336    0.029694     0.118084       0.006053
# TotalBsmtSF    ...    0.438181    0.191504     0.226590       0.098801
# 1stFlrSF       ...    0.438617    0.192370     0.187688       0.065123
# 2ndFlrSF       ...    0.110939    0.073548     0.203469       0.068514
# LowQualFinSF   ...    0.083076    0.016849     0.004788       0.067386
# GrLivArea      ...    0.416106    0.206284     0.318050       0.018267
# BsmtFullBath   ...    0.147745    0.161654     0.055966       0.050371
# BsmtHalfBath   ...    0.014424    0.043292     0.019680       0.008484
# FullBath       ...    0.380562    0.170447     0.250219       0.119326
# HalfBath       ...    0.136275    0.084168     0.186347       0.094106
# BedroomAbvGr   ...    0.074157    0.047102     0.091915       0.037539
# KitchenAbvGr   ...    0.053570    0.086689     0.066045       0.036346
# TotRmsAbvGrd   ...    0.278356    0.135513     0.211180       0.012327
# Fireplaces     ...    0.228616    0.181155     0.154869       0.014115
# GarageYrBlt    ...    0.546216    0.207749     0.208123       0.300494
# GarageCars     ...    0.876183    0.187554     0.182768       0.147613
# GarageArea     ...    1.000000    0.190339     0.209080       0.118188
# WoodDeckSF     ...    0.190339    1.000000     0.038730       0.127295
# OpenPorchSF    ...    0.209080    0.038730     1.000000       0.095707
# EnclosedPorch  ...    0.118188    0.127295     0.095707       1.000000
# 3SsnPorch      ...    0.036225    0.028089     0.005581       0.036499
# ScreenPorch    ...    0.039059    0.072163     0.058042       0.082509
# PoolArea       ...    0.057579    0.078637     0.064249       0.062261
# MiscVal        ...    0.022926    0.006653     0.016536       0.017994
# MoSold         ...    0.032084    0.016974     0.073625       0.029406
# YrSold         ...    0.025032    0.033902     0.051409       0.011136
#
#                3SsnPorch  ScreenPorch  PoolArea   MiscVal    MoSold    YrSold
# MSSubClass      0.047031     0.034613  0.007323  0.008987  0.016272  0.020575
# LotFrontage     0.073082     0.042204  0.188812  0.009436  0.013754  0.010652
# LotArea         0.031732     0.042184  0.098503  0.050596  0.001977  0.030752
# OverallQual     0.028651     0.054074  0.051522  0.026364  0.071711  0.022683
# OverallCond     0.031397     0.045030  0.002206  0.068612  0.001123  0.049258
# YearBuilt       0.024459     0.045819  0.000428  0.031705  0.008248  0.015741
# YearRemodAdd    0.040240     0.047946  0.003406  0.006896  0.017601  0.038535
# MasVnrArea      0.015432     0.070172  0.027160  0.026903  0.009345  0.012538
# BsmtFinSF1      0.011988     0.073345  0.127861  0.009386  0.022549  0.012225
# BsmtFinSF2      0.029287     0.090358  0.047874  0.004457  0.012129  0.025953
# BsmtUnfSF       0.028662     0.023577  0.031879  0.023343  0.047179  0.040912
# TotalBsmtSF     0.031106     0.088505  0.120159  0.012932  0.021121  0.019857
# 1stFlrSF        0.053184     0.093983  0.125285  0.015598  0.041955  0.016590
# 2ndFlrSF        0.014545     0.024869  0.052031  0.019622  0.040089  0.016157
# LowQualFinSF    0.002967     0.032231  0.071465  0.003708  0.022235  0.019567
# GrLivArea       0.026576     0.088699  0.146112  0.005236  0.064271  0.028481
# BsmtFullBath    0.009559     0.029478  0.065021  0.021109  0.034614  0.067429
# BsmtHalfBath    0.023552     0.037262  0.023888  0.007890  0.035899  0.047432
# FullBath        0.035164     0.016274  0.031249  0.010657  0.059938  0.013250
# HalfBath        0.006303     0.064249  0.013512  0.003619  0.007352  0.011574
# BedroomAbvGr    0.013499     0.040291  0.064250  0.008628  0.054613  0.035459
# KitchenAbvGr    0.024508     0.052148  0.014044  0.061577  0.028253  0.031796
# TotRmsAbvGrd    0.001378     0.033897  0.077481  0.032591  0.047825  0.036781
# Fireplaces      0.010734     0.188897  0.086614  0.005774  0.050051  0.021474
# GarageYrBlt     0.016325     0.088942  0.020621  0.029444  0.002324  0.000066
# GarageCars      0.033421     0.040553  0.010591  0.039362  0.041364  0.037725
# GarageArea      0.036225     0.039059  0.057579  0.022926  0.032084  0.025032
# WoodDeckSF      0.028089     0.072163  0.078637  0.006653  0.016974  0.033902
# OpenPorchSF     0.005581     0.058042  0.064249  0.016536  0.073625  0.051409
# EnclosedPorch   0.036499     0.082509  0.062261  0.017994  0.029406  0.011136
# 3SsnPorch       1.000000     0.030306  0.007351  0.000915  0.012321  0.018068
# ScreenPorch     0.030306     1.000000  0.060554  0.033907  0.027727  0.011272
# PoolArea        0.007351     0.060554  1.000000  0.032448  0.039307  0.059224
# MiscVal         0.000915     0.033907  0.032448  1.000000  0.006226  0.004756
# MoSold          0.012321     0.027727  0.039307  0.006226  1.000000  0.144784
# YrSold          0.018068     0.011272  0.059224  0.004756  0.144784  1.000000
#
# [36 rows x 36 columns]

# %% [markdown]
# The above is hard to look at and interpret, so let's subset the matrix on values with absolute correlation above 0.6 and determine what to drop:

# %%
abs_corr[(abs_corr < 1) & (abs_corr >= .6)].dropna(1, 'all').dropna(0, 'all')
# Out:
#               YearBuilt  YearRemodAdd  BsmtFinSF1  TotalBsmtSF  1stFlrSF  \
# YearBuilt           NaN           NaN         NaN          NaN       NaN
# YearRemodAdd        NaN           NaN         NaN          NaN       NaN
# BsmtFinSF1          NaN           NaN         NaN          NaN       NaN
# TotalBsmtSF         NaN           NaN         NaN          NaN  0.787102
# 1stFlrSF            NaN           NaN         NaN     0.787102       NaN
# 2ndFlrSF            NaN           NaN         NaN          NaN       NaN
# GrLivArea           NaN           NaN         NaN          NaN       NaN
# BsmtFullBath        NaN           NaN     0.63395          NaN       NaN
# FullBath            NaN           NaN         NaN          NaN       NaN
# HalfBath            NaN           NaN         NaN          NaN       NaN
# BedroomAbvGr        NaN           NaN         NaN          NaN       NaN
# TotRmsAbvGrd        NaN           NaN         NaN          NaN       NaN
# GarageYrBlt    0.820937      0.627602         NaN          NaN       NaN
# GarageCars          NaN           NaN         NaN          NaN       NaN
# GarageArea          NaN           NaN         NaN          NaN       NaN
#
#               2ndFlrSF  GrLivArea  BsmtFullBath  FullBath  HalfBath  \
# YearBuilt          NaN        NaN           NaN       NaN       NaN
# YearRemodAdd       NaN        NaN           NaN       NaN       NaN
# BsmtFinSF1         NaN        NaN       0.63395       NaN       NaN
# TotalBsmtSF        NaN        NaN           NaN       NaN       NaN
# 1stFlrSF           NaN        NaN           NaN       NaN       NaN
# 2ndFlrSF           NaN   0.687815           NaN       NaN  0.616389
# GrLivArea     0.687815        NaN           NaN  0.605872       NaN
# BsmtFullBath       NaN        NaN           NaN       NaN       NaN
# FullBath           NaN   0.605872           NaN       NaN       NaN
# HalfBath      0.616389        NaN           NaN       NaN       NaN
# BedroomAbvGr       NaN        NaN           NaN       NaN       NaN
# TotRmsAbvGrd  0.611277   0.815201           NaN       NaN       NaN
# GarageYrBlt        NaN        NaN           NaN       NaN       NaN
# GarageCars         NaN        NaN           NaN       NaN       NaN
# GarageArea         NaN        NaN           NaN       NaN       NaN
#
#               BedroomAbvGr  TotRmsAbvGrd  GarageYrBlt  GarageCars  GarageArea
# YearBuilt              NaN           NaN     0.820937         NaN         NaN
# YearRemodAdd           NaN           NaN     0.627602         NaN         NaN
# BsmtFinSF1             NaN           NaN          NaN         NaN         NaN
# TotalBsmtSF            NaN           NaN          NaN         NaN         NaN
# 1stFlrSF               NaN           NaN          NaN         NaN         NaN
# 2ndFlrSF               NaN      0.611277          NaN         NaN         NaN
# GrLivArea              NaN      0.815201          NaN         NaN         NaN
# BsmtFullBath           NaN           NaN          NaN         NaN         NaN
# FullBath               NaN           NaN          NaN         NaN         NaN
# HalfBath               NaN           NaN          NaN         NaN         NaN
# BedroomAbvGr           NaN      0.701948          NaN         NaN         NaN
# TotRmsAbvGrd      0.701948           NaN          NaN         NaN         NaN
# GarageYrBlt            NaN           NaN          NaN         NaN         NaN
# GarageCars             NaN           NaN          NaN         NaN    0.876183
# GarageArea             NaN           NaN          NaN    0.876183         NaN

# %%
# Lets examine further the relationship between GarageYrBlt and [YearBuilt, YearRemodAdd]
sbn.scatterplot('YearBuilt', 'GarageYrBlt',data = df)
print(df.loc[df['YearBuilt'] > df['GarageYrBlt'],['YearBuilt','GarageYrBlt']])

# %%
sbn.scatterplot('GarageYrBlt', 'YearRemodAdd',data = df)
