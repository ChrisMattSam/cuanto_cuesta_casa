# %% [markdown]
# # Introduction
#
# The idea for this notebook is to approach the problem from something easy to understand, in this case regression on purely continuous variables, before scaling up in complexity.  We'll perform the usual multiple regression before regularizing accordingly.

# %% [markdown]
# First lets read in the data and briefly look at the label we're trying to predict:

# %%
import pandas as pd
import numpy as np
import seaborn as sbn
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy import stats


df =  pd.read_csv('data/train.csv').set_index('Id')
df_test = pd.concat([pd.read_csv('data/test.csv').set_index('Id'),
                    pd.read_csv('data/sample_submission.csv').set_index('Id')],1)
df = pd.concat([df, df_test])
print(df.SalePrice.describe())
# Out:
# count      2919.000000
# mean     180052.854647
# std       57381.565721
# min       34900.000000
# 25%      154795.084126
# 50%      176734.841494
# 75%      191895.744157
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Initial Outlier Detection
#
# From intro stats lets check the data with the 68-95-99.7 rule with respect to one-, two-, and three-standard deviations

# %%
def trim(df,std_dev=1, scale = False, return_df = False):
    '''
    From intro stats, check the 68-95-99.7 rule with respect to 1-sd, 2-sd,
    3-sd.
    '''
    mu = df.SalePrice.mean()
    sigma = df.SalePrice.std()
    if scale:
        scale = 100000
    else:
        scale = 1
    trimmed_df = df.loc[(abs(df.SalePrice) <= (mu + std_dev*sigma))]
    data = trimmed_df.SalePrice
    if return_df:
        return trimmed_df
    else:
        label = str(std_dev) + "-Sigma, " + str(round(100*data.shape[0]/df.SalePrice.shape[0],2)) + "% of dataset"
        sbn.distplot(data/scale, kde_kws = {"label": label})
    
sbn.distplot(df.SalePrice/100000, kde_kws={"label": "Original data"})
trim(df,1,True)
trim(df,2,True)
trim(df,3,True)
plt.title('Scaled Standard Deviations')
plt.show()

# %% [markdown]
# Note the large peak in the distribution, prompting us to check skewness and kurtosis for features "SalePrice" and the log of SalePrice, the latter in reference to the work done by another Kaggle notebook (https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python by Pedro Marcelino)

# %%
def check_skew_kurtosis(df, feature = 'SalePrice', pics_only = False,):
    '''
    Overlay a normal pdf onto the plot of the feature of interest to visually
    observe its deviation from normality
    '''
    y = df[feature]
    sbn.distplot(y, fit=norm)
    plt.figure()
    stats.probplot(y, plot=plt)
    plt.show()
    print('The kurtosis: ' + str(stats.kurtosis(y)))
    print('The skew: ' + str(stats.skew(y)))
    
check_skew_kurtosis(df)
# Out:
# The kurtosis: 14.63787275141075
# The skew: 2.5479382085715123

# %% [markdown]
# Observing the skewness and kurtosis, lets take the log of the SalePrice and try to observe how much closer we can get the distribution to normality:

# %%
df['log_SalePrice'] = np.log(df['SalePrice'])
check_skew_kurtosis(df,'log_SalePrice')
# Out:
# The kurtosis: 3.731625568003553
# The skew: -0.15030378710305026

# %% [markdown]
# We see that both the distribution and theoretical quantiles align more closely with that of a normally distributed feature, with correspondingly smaller kurtosis and skewness. From the article (https://www.spcforexcel.com/knowledge/basic-statistics/are-skewness-and-kurtosis-useful-statistics) and other justification we deduce skewness and kurtosis not to be particularly useful, hence we may try regression with both logged and unlogged SalePrice and compare accordingly.
#
# From the graphics we trim the dataset to records with feature SalePrice falling within two standard-deviations of the mean SalePrice.  We may come back and attempt regression without trimming the dataset.

# %%
df = trim(df,2,return_df = True)

# %% [markdown]
# # Feature Selection

# %% [markdown]
# First lets look at all features satisfying numerical type

# %%
print(df.select_dtypes(exclude = ['object']).head())
# Out:
#     MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id
# 1           60         65.0     8450            7            5       2003
# 2           20         80.0     9600            6            8       1976
# 3           60         68.0    11250            7            5       2001
# 4           70         60.0     9550            7            5       1915
# 5           60         84.0    14260            8            5       2000
#
#     YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  OpenPorchSF  \
# Id                                                    ...
# 1           2003       196.0       706.0         0.0  ...           61
# 2           1976         0.0       978.0         0.0  ...            0
# 3           2002       162.0       486.0         0.0  ...           42
# 4           1970         0.0       216.0         0.0  ...           35
# 5           2000       350.0       655.0         0.0  ...           84
#
#     EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  \
# Id
# 1               0          0            0         0        0       2    2008
# 2               0          0            0         0        0       5    2007
# 3               0          0            0         0        0       9    2008
# 4             272          0            0         0        0       2    2006
# 5               0          0            0         0        0      12    2008
#
#     SalePrice  log_SalePrice
# Id
# 1    208500.0      12.247694
# 2    181500.0      12.109011
# 3    223500.0      12.317167
# 4    140000.0      11.849398
# 5    250000.0      12.429216
#
# [5 rows x 38 columns]

# %% [markdown]
# We notice that some features having strictly numerical values aren't continuous, for example ordinal categoricals.  Lets exclude them right away and perform some quick data cleaning:

# %%
drop_cols = list(df.select_dtypes(exclude = ['number']).columns)
[drop_cols.append(col) for col in ['MSSubClass','OverallQual','OverallCond', 'MiscVal']]

'quick cleaning:'
df['LotFrontage'].replace(np.nan,0, inplace = True)
df['MasVnrArea'].replace(np.nan,0, inplace = True)

# %% [markdown]
# Next let's try to find features that correlate with each other and subsequently remove them from our dataset.  For this we only really care about the magnitude of correlation versus positive or negative

# %%
def abs_corr(df, drop_cols = [], min_val = .6, max_val = 1, plot_me = True, plot_x = 12, plot_y = 9):
    if len(drop_cols) > 0:
        drop_cols = list(set(drop_cols))
        df = df[[i for i in df.columns if i not in drop_cols]]
    abs_mtx = df.drop(columns = 'SalePrice').corr().abs()
    
    mtx = abs_mtx[(abs_mtx < max_val) & (abs_mtx >= min_val)].dropna(1, 'all').dropna(0, 'all')
    if plot_me:
        plt.subplots(figsize=(plot_x, plot_y))
        sbn.heatmap(mtx, vmax=.8, square=True)
        plt.show()
    else:
        return mtx

abs_corr(df.drop(columns = 'log_SalePrice'), drop_cols)

# %% [markdown]
# From the figure we can see that features 1stFlrSF and TotalBsmtSF are highly correlated. It isn't uncommon for the 1st floor's square footage to equal that of the basement, and not all houses have a basement but definitly have a first floor.
#
# Also, GarageCars highly correlates with GarageArea, and is less informative. Next, the YearBuilt correlates strongly with GarageYrBlt (agreeing with intuition), and is more informative.
# TotRmsAbvGrd highly correlates with GrLivArea, is less informative, and seems to be captured by living area as well as bedrooms above ground.  Therefore we add the following features to be dropped:

# %%
[drop_cols.append(i) for i in ['GarageYrBlt', 'GarageCars','TotalBsmtSF', 'TotRmsAbvGrd']]
abs_corr(df.drop(columns = 'log_SalePrice'), drop_cols)

# %% [markdown]
# The remaining correlations arent as strong, but we note 2ndFlrSF and GrLivArea. We'll leave them for now since I find them both to be informative for different reasons, but may drop one of them depending on model performance

# %%
df.drop(columns = drop_cols, inplace = True)

# %% [markdown]
# # Feature Engineering and Final Data Prep
#
# Right away lets alter the time field to a format we can use for the regression:

# %%
from operator import attrgetter
df.rename(columns = {'YrSold': 'year','MoSold':'month'}, inplace = True)
df['day'] = 1
df['date_sold'] = pd.to_datetime(df[['year', 'month','day']])
df['min_sell_date'] = df.date_sold.min()
min_sell_date = df['min_sell_date'].iloc[0]
df['months_since_sold'] = (df.date_sold.dt.to_period('M') - df.min_sell_date.dt.to_period('M')).apply(attrgetter('n'))
[df.drop(columns = date_col, inplace = True) for date_col in ['year', 'month','day', 'date_sold', 'min_sell_date']]


df['months_since_sold'].hist() # a quick histogram
plt.show()

# %% [markdown]
# Next lets look at missing values:

# %%
miss = df.isnull().sum()
miss.loc[miss >0]
# Out:
# BsmtFinSF1      1
# BsmtFinSF2      1
# BsmtUnfSF       1
# BsmtFullBath    2
# BsmtHalfBath    2
# GarageArea      1
# dtype: int64

# %%
for feature in ['BsmtFullBath','BsmtHalfBath','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','GarageArea']:
    print('Row of missing values for feature ' + feature+ ':')
    print(df.loc[df[feature].isna()])
    print('\n')
# Out:
# Row of missing values for feature BsmtFullBath:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2121         99.0     5940       1946          1950         0.0         NaN
# 2189        123.0    47007       1959          1996         0.0         0.0
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# Id                                               ...
# 2121         NaN        NaN       896         0  ...       280.0           0
# 2189         0.0        0.0      3820         0  ...       624.0           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 2121            0              0          0            0         0
# 2189          372              0          0            0         0
#
#           SalePrice  log_SalePrice  months_since_sold
# Id
# 2121  157680.227413      11.968324                 27
# 2189  281643.976117      12.548399                 30
#
# [2 rows x 29 columns]
#
#
# Row of missing values for feature BsmtHalfBath:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2121         99.0     5940       1946          1950         0.0         NaN
# 2189        123.0    47007       1959          1996         0.0         0.0
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# Id                                               ...
# 2121         NaN        NaN       896         0  ...       280.0           0
# 2189         0.0        0.0      3820         0  ...       624.0           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 2121            0              0          0            0         0
# 2189          372              0          0            0         0
#
#           SalePrice  log_SalePrice  months_since_sold
# Id
# 2121  157680.227413      11.968324                 27
# 2189  281643.976117      12.548399                 30
#
# [2 rows x 29 columns]
#
#
# Row of missing values for feature BsmtFinSF1:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2121         99.0     5940       1946          1950         0.0         NaN
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# Id                                               ...
# 2121         NaN        NaN       896         0  ...       280.0           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 2121            0              0          0            0         0
#
#           SalePrice  log_SalePrice  months_since_sold
# Id
# 2121  157680.227413      11.968324                 27
#
# [1 rows x 29 columns]
#
#
# Row of missing values for feature BsmtFinSF2:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2121         99.0     5940       1946          1950         0.0         NaN
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# Id                                               ...
# 2121         NaN        NaN       896         0  ...       280.0           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 2121            0              0          0            0         0
#
#           SalePrice  log_SalePrice  months_since_sold
# Id
# 2121  157680.227413      11.968324                 27
#
# [1 rows x 29 columns]
#
#
# Row of missing values for feature BsmtUnfSF:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2121         99.0     5940       1946          1950         0.0         NaN
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# Id                                               ...
# 2121         NaN        NaN       896         0  ...       280.0           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 2121            0              0          0            0         0
#
#           SalePrice  log_SalePrice  months_since_sold
# Id
# 2121  157680.227413      11.968324                 27
#
# [1 rows x 29 columns]
#
#
# Row of missing values for feature GarageArea:
#       LotFrontage  LotArea  YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  \
# Id
# 2577         50.0     9060       1923          1999         0.0       548.0
#
#       BsmtFinSF2  BsmtUnfSF  1stFlrSF  2ndFlrSF  ...  GarageArea  WoodDeckSF  \
# Id                                               ...
# 2577         0.0      311.0       942       886  ...         NaN         174
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# Id
# 2577            0            212          0            0         0
#
#           SalePrice  log_SalePrice  months_since_sold
# Id
# 2577  176889.171525      12.083279                 14
#
# [1 rows x 29 columns]

# %% [markdown]
# Looking at the data, the record at indices 2121 and 2189 are missing values for all basement-related features,
# so I presume this means there doesnt exist a basement. Also, missing GarageArea seems to indicate lackthereof. Impute accordingly and make final adjustmentes for modelling:

# %%
df.loc[df.index.isin([2121, 2189]),['BsmtFullBath', 'BsmtHalfBath']] = 0
df.loc[df.index == 2121, ['BsmtFinSF1','BsmtFinSF2','BsmtUnfSF']] = 0
df.loc[df['GarageArea'].isna(),['GarageArea']] = 0

#final check of missing vals
miss = df.isnull().sum()
miss.loc[miss >0]
# Out:
# Series([], dtype: int64)

# %%
'normalize'
df = df.sample(frac = 1) #shuffle in case the data came in an ordered manner
X = df.drop(columns = ['SalePrice','log_SalePrice'])
X = (X - X.mean())/X.std()
y = df['SalePrice']

# %% [markdown]
# # Modelling

# %%
from sklearn import linear_model as lm
from sklearn.model_selection import cross_validate as cv
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")# lasso generates a lot of warnings

baseline = cv(lm.LinearRegression(fit_intercept = True), X, y, cv = 20,
                  scoring = 'r2', return_estimator = True)
print('Multiple Regression:')
print('Largest R-squared: ' +  str(baseline['test_score'].max()))
# Out:
# Multiple Regression:
# Largest R-squared: 0.49251531985107655

# %% [markdown]
# Now lets regularize and see if we obtain better results

# %%
# Out:
# Ridge regression for multiple penalty terms:
# Penalty: 1
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 2
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 3
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 4
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 5
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 6
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 7
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 8
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 9
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
#
# Penalty: 10
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 11
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 12
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 13
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 14
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 15
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 16
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 17
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 18
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 19
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Penalty: 20
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
#
# Lasso regression for multiple penalty terms:
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 917596931.0537109, tolerance: 371228031.27655315
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2385111946.2719727, tolerance: 380163851.06302136
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2534569785.848877, tolerance: 373774079.4450247
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2053316889.3439941, tolerance: 364728500.61004496
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1656166659.4750977, tolerance: 380256875.535825
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2175915356.4523926, tolerance: 370723211.59699774
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2342081748.467041, tolerance: 375413861.29903
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1677669374.9799805, tolerance: 372428243.193642
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2499155579.895996, tolerance: 366860935.82780176
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2396310929.7348633, tolerance: 369057619.5273427
#   positive)
# Penalty: 1
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 920376208.314209, tolerance: 371228031.27655315
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2392608549.190918, tolerance: 380163851.06302136
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2542358990.4975586, tolerance: 373774079.4450247
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2059000480.2045898, tolerance: 364728500.61004496
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1661988868.8886719, tolerance: 380256875.535825
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2181853423.664795, tolerance: 370723211.59699774
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2348691692.015381, tolerance: 375413861.29903
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1683731841.338623, tolerance: 372428243.193642
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2505669664.82666, tolerance: 366860935.82780176
#   positive)
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2403532725.220215, tolerance: 369057619.5273427
#   positive)
# Penalty: 2
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# C:\Users\csampah\Anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2393255365.9589844, tolerance: 380163851.06302136
#   positive)
# Penalty: 3
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 4
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 5
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 6
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 7
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 8
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 9
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 10
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 11
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 12
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 13
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 14
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 15
# Smallest R-squared: 0.258
# Largest R-squared: 0.485
# Penalty: 16
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
# Penalty: 17
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
# Penalty: 18
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
# Penalty: 19
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
# Penalty: 20
# Smallest R-squared: 0.259
# Largest R-squared: 0.485
