# %%
import pandas as pd
import numpy as np
import pylab as plt
from sklearn import linear_model as lm
import seaborn as sbn

# %% [markdown]
# This will be a regression based notebook for the kaggle competition found here: https://www.kaggle.com/c/house-prices-advanced-regression-techniques.  The goal is to utilize multivariate regression before implementing regularizers ridge and lasso.
#
#  We first perform some exploratory analysis

# %%
df = pd.read_csv('data/train.csv')
df.set_index('Id', inplace= True)
print(df.SalePrice.describe())
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Initial Outlier Detection
#
# From intro stats lets check the data with the 68-95-99.7 rule with respect to one-, two-, and three-standard deviations

# %%
def trim(df,std_dev=1, scale = False, return_df = False):
    mu = df.SalePrice.mean()
    sigma = df.SalePrice.std()
    if scale:
        scale = 100000
    else:
        scale = 1
    trimmed_df = df.loc[(abs(df.SalePrice) <= (mu + std_dev*sigma))]
    data = trimmed_df.SalePrice
    if return_df:
        return trimmed_df
    else:
        label = str(std_dev) + "-Sigma, " + str(round(100*data.shape[0]/df.SalePrice.shape[0],2)) + "% of dataset"
        sbn.distplot(data/scale, kde_kws = {"label": label})
    

sbn.distplot(df.SalePrice/100000, kde_kws={"label": "All data"})
trim(df,1,True)
trim(df,2,True)
trim(df,3,True)

# %%
trim(df,1,True)
trim(df,2,True)
trim(df,3,True)
plt.title('Scaled Standard Deviations')
# Out:
# Text(0.5, 1.0, 'Scaled Standard Deviations')

# %% [markdown]
# To keep as many records as possible, we subset the data on records within 2 standard deviations of the mean.  Next we'll try to eliminate redundant numerical features by examing the absolute-correlation matrix:

# %%
df = trim(df,2,return_df = True)

# %% [markdown]
# # Feature Selection: Numerical features

# %%
def abs_corr(df, drop_cols = [], min_val = .6, max_val = 1):
    if len(drop_cols) > 0:
        drop_cols = list(set(drop_cols))
        df = df[[i for i in df.columns if i not in drop_cols]]
    abs_mtx = df.select_dtypes(exclude = ['object']).drop(columns = 'SalePrice').corr().abs()
    return abs_mtx[(abs_mtx < max_val) & (abs_mtx >= min_val)].dropna(1, 'all').dropna(0, 'all')
abs_corr(df)
# Out:
#               YearBuilt  YearRemodAdd  BsmtFinSF1  TotalBsmtSF  1stFlrSF  \
# YearBuilt           NaN           NaN         NaN          NaN       NaN
# YearRemodAdd        NaN           NaN         NaN          NaN       NaN
# BsmtFinSF1          NaN           NaN         NaN          NaN       NaN
# TotalBsmtSF         NaN           NaN         NaN          NaN  0.787102
# 1stFlrSF            NaN           NaN         NaN     0.787102       NaN
# 2ndFlrSF            NaN           NaN         NaN          NaN       NaN
# GrLivArea           NaN           NaN         NaN          NaN       NaN
# BsmtFullBath        NaN           NaN     0.63395          NaN       NaN
# FullBath            NaN           NaN         NaN          NaN       NaN
# HalfBath            NaN           NaN         NaN          NaN       NaN
# BedroomAbvGr        NaN           NaN         NaN          NaN       NaN
# TotRmsAbvGrd        NaN           NaN         NaN          NaN       NaN
# ...

# %%
# Lets examine further the relationship between GarageYrBlt and [YearBuilt, YearRemodAdd]
sbn.scatterplot('YearBuilt', 'GarageYrBlt',data = df)
print(df.loc[df['YearBuilt'] > df['GarageYrBlt'],['YearBuilt','GarageYrBlt']])
# Out:
#       YearBuilt  GarageYrBlt
# Id
# 30         1927       1920.0
# 94         1910       1900.0
# 325        1967       1961.0
# 601        2005       2003.0
# 737        1950       1949.0
# 1104       1959       1954.0
# 1377       1930       1925.0
# 1415       1923       1922.0
# 1419       1963       1962.0

# %%
# Next let's compare the year a garage was built and the year the house was last remodelled:
sbn.scatterplot('GarageYrBlt', 'YearRemodAdd',data = df)

# %% [markdown]
# Because GarageYrBlt is correlated with two other features, and its relevant data still seems to be captured by the other two features, we drop it from our dataset.Next we'll get rid of feature BsmtFullBath because its correlated with BsmtFinSF1 and is less informative, and because its categorical it'd require the creation of more features (e.g. dummy variables)

# %%
df.BsmtFullBath.value_counts() # just a double-check
drop_cols = ['GarageYrBlt','BsmtFullBath']

# %%
# Next we look at basement square feet and 1st floor sq feet
print(df.loc[(df['TotalBsmtSF'] == 0) & (df['1stFlrSF'] > 0)].shape)
print(df.loc[(df['TotalBsmtSF'] > 0) & (df['1stFlrSF'] == 0)].shape)
print(df.loc[df['TotalBsmtSF'] > df['1stFlrSF'],['TotalBsmtSF','1stFlrSF'] ])
print('\nLets check for houses without first floors nor basements:')
print(df.loc[df['1stFlrSF']==0].shape)
print(df.loc[df['TotalBsmtSF']==0].shape)
# Out:
# (37, 80)
# (0, 80)
#       TotalBsmtSF  1stFlrSF
# Id
# 42           1350      1328
# 127          1078       958
# 154          1602      1252
# 247          1020       908
# 270          1143      1113
# 272          1385      1363
# 280          1160      1156
# 333          3206      1629
# 365           796       790
# 385          1580      1079
# 514          1084      1080
# 536          1117       820
# 547          1065       915
# 769          1860      1836
# 786          1372      1342
# 808          1324      1072
# 828          1454      1434
# 830           600       520
# 832           600       520
# 877          1064      1040
# 919          1104       912
# 1027         1268      1264
# 1192          776       764
# 1265         1405      1337
# 1288         1624      1582
# 1299         6110      4692
# 1302          771       753
# 1336         1350      1334
# 1365          600       520
# 1399         1208      1136
# 1404         1485      1464
#
# ...

# %% [markdown]
# Some things to note: in most of the cases where basement square footage is larger than that of the 1st floor, the difference isn't large, and some houses do not have basements, but all houses have a 1st floor. Therefore we'll drop total basement square footage accordingly.

# %%
drop_cols.append('TotalBsmtSF')
abs_corr(df, drop_cols)
# Out:
#               2ndFlrSF  GrLivArea  FullBath  HalfBath  BedroomAbvGr  \
# 2ndFlrSF           NaN   0.687815       NaN  0.616389           NaN
# GrLivArea     0.687815        NaN  0.605872       NaN           NaN
# FullBath           NaN   0.605872       NaN       NaN           NaN
# HalfBath      0.616389        NaN       NaN       NaN           NaN
# BedroomAbvGr       NaN        NaN       NaN       NaN           NaN
# TotRmsAbvGrd  0.611277   0.815201       NaN       NaN      0.701948
# GarageCars         NaN        NaN       NaN       NaN           NaN
# GarageArea         NaN        NaN       NaN       NaN           NaN
#
#               TotRmsAbvGrd  GarageCars  GarageArea
# 2ndFlrSF          0.611277         NaN         NaN
# GrLivArea         0.815201         NaN         NaN
# FullBath               NaN         NaN         NaN
# HalfBath               NaN         NaN         NaN
# BedroomAbvGr      0.701948         NaN         NaN
# ...

# %% [markdown]
# From the trimmed absolute-correlation matrix we quickly identify features GarageCars and TotRmsAbvGrd to be removable, as the variables they are highly correlated with provide more detailed information

# %%
[drop_cols.append(i) for i in ['GarageCars','TotRmsAbvGrd']]
drop_cols
# Out:
# ['GarageYrBlt', 'BsmtFullBath', 'TotalBsmtSF', 'GarageCars', 'TotRmsAbvGrd']

# %%
abs_corr(df, drop_cols)
# Out:
#            2ndFlrSF  GrLivArea  FullBath  HalfBath
# 2ndFlrSF        NaN   0.687815       NaN  0.616389
# GrLivArea  0.687815        NaN  0.605872       NaN
# FullBath        NaN   0.605872       NaN       NaN
# HalfBath   0.616389        NaN       NaN       NaN

# %%
# Lets take a closer look between general living area and 2nd floor square feet: 
sbn.scatterplot('GrLivArea','2ndFlrSF', data = df)

# %% [markdown]
# Because not all houses have a second floor, but may still have a sizable above-ground living area, between these two variables we'll drop 2nd-floor square feet.  Because the other correlations are comparatively small, even though technically above our threshold of.6, we'll still keep them in the analysis for now.

# %%
drop_cols.append('2ndFlrSF')
df.drop(columns = drop_cols, inplace = True)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.select_dtypes(exclude = ['number']).head()
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# Id
# 1        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 2        RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 3        RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 4        RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 5        RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#    Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# Id                          ...
# 1       CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 2       Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 3       CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 4       Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 5       NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...
